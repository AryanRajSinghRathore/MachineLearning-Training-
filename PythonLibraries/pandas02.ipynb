# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
df[['total_bill','tip','smoker']].head()
# Out:
#    total_bill   tip smoker
# 0       16.99  1.01     No
# 1       10.34  1.66     No
# 2       21.01  3.50     No
# 3       23.68  3.31     No
# 4       24.59  3.61     No

# %%
## FOR ROWS
df.loc[0:36]#loc includes the last number
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
df.iloc[0:4,['total_bill']]## iloc dont need name of the colummns only index is necceray
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\AI-ML\pandas02.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/AI-ML/pandas02.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df.iloc[0:4,['total_bill']]## iloc dont need name of the colummns only index is necceray
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1652, in _iLocIndexer._getitem_tuple(self, tup)
# ...

# %%
df.iloc[0:4,0:3]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male

# %%
df.loc[242:,['time','size']]
# Out:
#        time  size
# 242  Dinner     2
# 243  Dinner     2

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df[df['total_bill']<=10]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 30         9.55  1.45    Male     No   Sat  Dinner     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 53         9.94  1.56    Male     No   Sun  Dinner     2
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# 135        8.51  1.25  Female     No  Thur   Lunch     2
# 145        8.35  1.50  Female     No  Thur   Lunch     2
# 148        9.78  1.73    Male     No  Thur   Lunch     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# ...

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
df['total_bill'].sum()
# Out:
# 4827.77

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
a=list(df['day'].value_counts().index)
a
# Out:
# ['Sat', 'Sun', 'Thur', 'Fri']

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df[(df['smoker']=='No') & (df['day']=='Sun')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# 8         15.04  1.96    Male     No  Sun  Dinner     2
# 9         14.78  3.23    Male     No  Sun  Dinner     2
# 10        10.27  1.71    Male     No  Sun  Dinner     2
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 12        15.42  1.57    Male     No  Sun  Dinner     2
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 14        14.83  3.02  Female     No  Sun  Dinner     2
# 15        21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
df2=df[(df['total_bill']<=25)& (df['smoker']=='Yes') & (df['time']=='Dinner')][['total_bill','tip']]

# %%
df2
# Out:
#      total_bill   tip
# 58        11.24  1.76
# 60        20.29  3.21
# 61        13.81  2.00
# 62        11.02  1.98
# 63        18.29  3.76
# 67         3.07  1.00
# 69        15.01  2.09
# 76        17.92  3.08
# 92         5.75  1.00
# 93        16.32  4.30
# 97        12.03  1.50
# 98        21.01  3.00
# 100       11.35  2.50
# 101       15.38  3.00
# 103       22.42  3.48
# 105       15.36  1.64
# 106       20.49  4.06
# 109       14.31  4.00
# 164       17.51  3.00
# 168       10.59  1.61
# 169       10.63  2.00
# 171       15.81  3.16
# 172        7.25  5.15
# 174       16.82  4.00
# 176       17.89  2.00
# 177       14.48  2.00
# 178        9.60  4.00
# 181       23.33  5.65
# 183       23.17  6.50
# 186       20.90  3.50
# 188       18.15  3.50
# 189       23.10  4.00
# 190       15.69  1.50
# 208       24.27  2.03
# 209       12.76  2.23
# 213       13.27  2.50
# 215       12.90  1.10
# 217       11.59  1.50
# 218        7.74  1.44
# 229       22.12  2.88
# ...

# %%
df2.to_csv('filter_data.csv',index=False)

# %%
#to change the datatype of any column
df['total_bill'].astype('int')
# Out:
# 0      16
# 1      10
# 2      21
# 3      23
# 4      24
#        ..
# 239    29
# 240    27
# 241    22
# 242    17
# 243    18
# Name: total_bill, Length: 244, dtype: int32

# %%
df.sort_values(by='total_bill')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
df['time'].map({'Dinner':0,'Lunch':1})
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 239    0
# 240    0
# 241    0
# 242    0
# 243    0
# Name: time, Length: 244, dtype: int64
